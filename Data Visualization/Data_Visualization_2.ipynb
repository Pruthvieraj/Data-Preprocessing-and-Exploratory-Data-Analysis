# %%
import matplotlib.pyplot as plt   #Import library

# %%
# %matplotlib inline
#Enable inline plotting

# %%
import numpy as np
x = np.linspace(0, 5, 11)   #Generate 11 evenly spaced values from 0 to 5
y = x ** 2  #Compute y as square of x

# %%
x   #Display values of x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y  #Display values of y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y, 'r') #'r' is the color red
plt.xlabel('X Axis Title Here')   #Set x-axis label
plt.ylabel('Y Axis Title Here')   #Set y-axis label
plt.title('String Title Here')    #Set plot title
plt.show()

# %% [markdown]
# **Creating multiple plots on same canvas**

# %%
#plt.subplot(nrows, ncolumns, plot_number)
plt.subplot(1,2,1)  #First subplot
plt.plot(x, y, 'r--')
plt.subplot(1,2,2) #Second subplot
plt.plot(y, x, 'g*-')

# %%
#Create Figure(empty canvas)
fig = plt.figure()

#add set of axes to figure
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) #left, bottom, width, height (range 0 to 1)
#Plot on that set of axes
axes.plot(x, y, 'b')
axes.set_xlabel('Set X Label') # Notice the use of set_ to begin methods
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
#creates blank canvas
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) #main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) #inset axes
#Large Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes1')
axes1.set_ylabel('Y_label_axes1')
axes1.set_title('Axes 1 Title')
#Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title')
# Out:
# Text(0.5, 1.0, 'Axes 2 Title')

# %%
#use similar to plt.figure() except use tuple unpacking to grab fig and axes
fig, axes = plt.subplots()

#now use the axes object to add stuff to plot
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
#empty canvas of 1 by 2 subplots
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
for ax in axes:
    ax.plot(x, y, 'r')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')
#display the figure object
fig

# %%
fig = plt.figure(figsize = (8,4), dpi = 100)

# %%
fig, axes = plt.subplots(figsize=(12,3)) #Create figure and axes with specified size
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
fig.savefig("filename.png")   #Save the current figure as a PNG file

# %%
fig.savefig("figure1.png", dpi=200) #Save figure as PNG with 200 DPI

# %%
fig = plt.figure() #Create a figure

ax = fig.add_axes([0,0,1,1]) #Add axes to the figure

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")
ax.legend()    #Add legend to differentiate lines

# %%
#lots of options

ax.legend(loc=1) # upper right corner
ax.legend(loc=2) # upper left corner
ax.legend(loc=3) # lower left corner
ax.legend(loc=4) # lower right corner

# .. many more options are available

#most common to choose
ax.legend(loc=0) # let matplotlib decide the optimal location
fig
#run all loc pos

# %%
#matlab style line color and style
fig, ax = plt.subplots()
ax.plot(x, x**2, 'b.-') #blue line with dots
ax.plot(x, x**3, 'y-o') #yellow solid line with dots

# %%
fig, ax = plt.subplots()
ax.plot(x, x+1, color='blue', alpha=0.5)   #half transparent
ax.plot(x, x+2, color='#8B008B')           #RGB hex code
ax.plot(x, x+3, color='#FF8C00')           #RGB hex code

# %% [markdown]
# **line and marker styles**

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(x, x+1, color = 'red', linewidth = 0.25)
ax.plot(x, x+2, color = 'red', linewidth = 0.50)
ax.plot(x, x+3, color = 'red', linewidth = 1.00)
ax.plot(x, x+4, color = 'red', linewidth = 2.00)

#possible linestyle options '-', '-,', ':', 'steps'
ax.plot(x, x+5, color = 'green', lw = 3, linestyle = '-')
ax.plot(x, x+6, color = 'green', lw = 3, ls = '--')
ax.plot(x, x+7, color = 'green', lw = 3, ls = ':')

#custom dash
line, = ax.plot(x, x+8, color = 'black', lw = 1.50)
line.set_dashes([5, 10, 15, 10]) #format: line length, space length, ...
#possible marker symbols: marker= '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4',...
ax.plot(x, x+ 9, color = 'blue', lw = 3, ls = '-', marker = '+')
ax.plot(x, x+10, color = 'blue', lw = 3, ls = '--', marker = 'o')
ax.plot(x, x+11, color = 'blue', lw = 3, ls = '-', marker = 's')
ax.plot(x, x+12, color = 'blue', lw = 3, ls = '--', marker = '1')
#marker size and color
ax.plot(x, x+13, color='purple', lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color='purple', lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color='purple', lw=1, ls='-', marker='o', markersize=8, markerfacecolor='red')
ax.plot(x, x+16, color='purple', lw=1, ls='-', marker='s', markersize=8, markerfacecolor='yellow', markeredgewidth=3, markeredgecolor='green');

# %% [markdown]
# **Plot Range**

# %%
#Create 1 row and 3 column subplots with custom size
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

#First subplot: default axes ranges
axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

#Second subplot: tight axes around the data
axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

#Third subplot: custom axes range
axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])  #Set y-axis range
axes[2].set_xlim([2, 5])   #Set x-axis range
axes[2].set_title("custom axes range")
# Out:
# Text(0.5, 1.0, 'custom axes range')

# %% [markdown]
# **special plot types**

# %%
plt.scatter(x, y)    #Create scatter plot of x vs y

# %%
#Import sample function from random
from random import sample

#Generate 100 random integers between 1 and 999
data = sample(range(1, 1000), 100)

#Plot histogram of the random data
plt.hist(data)
# Out:
# (array([15., 11., 11.,  4., 12.,  7., 11., 11., 10.,  8.]),
#  array([  1. , 100.2, 199.4, 298.6, 397.8, 497. , 596.2, 695.4, 794.6,
#         893.8, 993. ]),
#  <BarContainer object of 10 artists>)

# %%
#Generate three datasets with different standard deviations
data = [np.random.normal(0, std, 100) for std in range(1, 4)]
#Display the generated data
data
#Create a rectangular box plot
plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e1200c7b020>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e1200ca1fa0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x7e1201cf8200>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7e1200ca25a0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7e1200ca28a0>,
# ...
#  'means': []}
